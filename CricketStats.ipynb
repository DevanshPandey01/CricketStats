# %%
import pandas as pd

# %%
df = pd.read_csv('CricketStats.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df = df.rename(columns={"NO":'NotOuts',"Mat":"Matches","HS":"HighestScore","Ave":"Avg","BF":"BallsFaced","SR":"StrikeRate"})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  NotOuts  Runs HighestScore  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996          334
# 1    HC Brook (ENG)  2022-2023       12    20        1  1181          186
# 2    AC Voges (AUS)  2015-2016       20    31        7  1485         269*
# 3   RG Pollock (SA)  1963-1970       23    41        4  2256          274
# 4   GA Headley (WI)  1930-1954       22    40        4  2190         270*
#
#      Avg BallsFaced  StrikeRate  100  50  0    4s  6s
# 0  99.94      9800+       58.60   29  13  7  626+   6
# 1  62.15       1287       91.76    4   7  1   141  23
# 2  61.87       2667       55.68    5   4  2   186   5
# 3  60.97      1707+       54.48    7  11  1  246+  11
# 4  60.83       416+       56.00   10   5  2  104+   1

# %%
df.isnull().any()
# Out:
# Player          False
# Span            False
# Matches         False
# Inns            False
# NotOuts         False
# Runs            False
# HighestScore    False
# Avg             False
# BallsFaced       True
# StrikeRate      False
# 100             False
# 50              False
# 0               False
# 4s              False
# 6s              False
# dtype: bool

# %%
df[df['BallsFaced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  NotOuts  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81        5  4455
# 15       CL Walcott (WI)  1948-1960       44    74        7  3798
# 56  Hon.FS Jackson (ENG)  1893-1905       20    33        4  1415
#
#    HighestScore    Avg BallsFaced  StrikeRate  100  50  0    4s  6s
# 8           207  58.61        NaN         0.0   15  19  6  258+   2
# 15          220  56.68        NaN         0.0   15  14  1  107+  11
# 56         144*  48.79        NaN         0.0    5   6  3   51+   0

# %%
df['BallsFaced']=df['BallsFaced'].fillna(0)

# %%
df[df['Player']=="ED Weekes (WI)"]
# Out:
#            Player  Matches  Inns  NotOuts  Runs  HighestScore    Avg  \
# 8  ED Weekes (WI)       48    81        5  4455           207  58.61
#
#   BallsFaced  StrikeRate  100  50  0   4s 6s StartYear EndYear
# 8          0         0.0   15  19  6  258  2      1948    1958

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 62, dtype: bool

# %%
df[df["Player"].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, NotOuts, Runs, HighestScore, Avg, BallsFaced, StrikeRate, 100, 50, 0, 4s, 6s, StartYear, EndYear]
# Index: []

# %%
df[df["Player"].isin(["GS Sobers (WI)","BC Lara (ICC/WI)","V Kohli (IND)"])]
# Out:
#               Player  Matches  Inns  NotOuts   Runs  HighestScore    Avg  \
# 10    GS Sobers (WI)       93   160       21   8032           365  57.78
# 21  BC Lara (ICC/WI)      131   232        6  11953           400  52.88
# 52     V Kohli (IND)      113   191       11   8848           254  49.15
#
#    BallsFaced  StrikeRate  100  50   0    4s  6s StartYear EndYear
# 10       4063       53.58   26  30  12   593  32      1954    1974
# 21      19753       60.51   34  48  17  1559  88      1990    2006
# 52      15924       55.56   29  30  14   991  26      2011    2024

# %%
df=df.drop_duplicates()

# %%
df.head()
# Out:
#              Player  Matches  Inns  NotOuts  Runs  HighestScore    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996           334  99.94
# 1    HC Brook (ENG)       12    20        1  1181           186  62.15
# 2    AC Voges (AUS)       20    31        7  1485           269  61.87
# 3   RG Pollock (SA)       23    41        4  2256           274  60.97
# 4   GA Headley (WI)       22    40        4  2190           270  60.83
#
#   BallsFaced  StrikeRate  100  50  0   4s  6s StartYear EndYear
# 0       9800       58.60   29  13  7  626   6      1928    1948
# 1       1287       91.76    4   7  1  141  23      2022    2023
# 2       2667       55.68    5   4  2  186   5      2015    2016
# 3       1707       54.48    7  11  1  246  11      1963    1970
# 4        416       56.00   10   5  2  104   1      1930    1954

# %%
#df["Span"].str.split(pat='-')

# %%
#df['StartYear']=df["Span"].str.split(pat="-").str[0]

# %%
#df['EndYear']=df["Span"].str.split(pat="-").str[1]

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  NotOuts  Runs HighestScore  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996          334
# 1    HC Brook (ENG)  2022-2023       12    20        1  1181          186
# 2    AC Voges (AUS)  2015-2016       20    31        7  1485         269*
# 3   RG Pollock (SA)  1963-1970       23    41        4  2256          274
# 4   GA Headley (WI)  1930-1954       22    40        4  2190         270*
#
#      Avg BallsFaced  StrikeRate  100  50  0    4s  6s StartYear EndYear
# 0  99.94      9800+       58.60   29  13  7  626+   6      1928    1948
# 1  62.15       1287       91.76    4   7  1   141  23      2022    2023
# 2  61.87       2667       55.68    5   4  2   186   5      2015    2016
# 3  60.97      1707+       54.48    7  11  1  246+  11      1963    1970
# 4  60.83       416+       56.00   10   5  2  104+   1      1930    1954

# %%
df=df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  NotOuts  Runs HighestScore    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996          334  99.94
# 1    HC Brook (ENG)       12    20        1  1181          186  62.15
# 2    AC Voges (AUS)       20    31        7  1485         269*  61.87
# 3   RG Pollock (SA)       23    41        4  2256          274  60.97
# 4   GA Headley (WI)       22    40        4  2190         270*  60.83
#
#   BallsFaced  StrikeRate  100  50  0    4s  6s StartYear EndYear
# 0      9800+       58.60   29  13  7  626+   6      1928    1948
# 1       1287       91.76    4   7  1   141  23      2022    2023
# 2       2667       55.68    5   4  2   186   5      2015    2016
# 3      1707+       54.48    7  11  1  246+  11      1963    1970
# 4       416+       56.00   10   5  2  104+   1      1930    1954

# %%
df
# Out:
#                Player  Matches  Inns  NotOuts  Runs HighestScore    Avg  \
# 0    DG Bradman (AUS)       52    80       10  6996          334  99.94
# 1      HC Brook (ENG)       12    20        1  1181          186  62.15
# 2      AC Voges (AUS)       20    31        7  1485         269*  61.87
# 3     RG Pollock (SA)       23    41        4  2256          274  60.97
# 4     GA Headley (WI)       22    40        4  2190         270*  60.83
# ..                ...      ...   ...      ...   ...          ...    ...
# 60   KD Walters (AUS)       74   125       14  5357          250  48.26
# 61  GC Smith (ICC/SA)      117   205       13  9265          277  48.25
# 62  WH Ponsford (AUS)       29    48        4  2122          266  48.22
# 63    SJ McCabe (AUS)       39    62        5  2748          232  48.21
# 64   DR Jardine (ENG)       22    33        6  1296          127  48.00
#
#    BallsFaced  StrikeRate  100  50   0    4s  6s StartYear EndYear
# ...

# %%
df.head()

# %%
df.dtypes

# %%
df['HighestScore']=df['HighestScore'].str.split(pat='*').str[0]

# %%
df['BallsFaced']=df['BallsFaced'].str.split(pat='+').str[0]

# %%
df.head(2)
# Out:
#              Player  Matches  Inns  NotOuts  Runs HighestScore    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996          334  99.94
# 1    HC Brook (ENG)       12    20        1  1181          186  62.15
#
#   BallsFaced  StrikeRate  100  50  0    4s  6s StartYear EndYear
# 0       9800       58.60   29  13  7  626+   6      1928    1948
# 1       1287       91.76    4   7  1   141  23      2022    2023

# %%
df['4s']=df['4s'].str.split(pat='+').str[0]

# %%
df.head(5)
# Out:
#              Player  Matches  Inns  NotOuts  Runs HighestScore    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996          334  99.94
# 1    HC Brook (ENG)       12    20        1  1181          186  62.15
# 2    AC Voges (AUS)       20    31        7  1485          269  61.87
# 3   RG Pollock (SA)       23    41        4  2256          274  60.97
# 4   GA Headley (WI)       22    40        4  2190          270  60.83
#
#   BallsFaced  StrikeRate  100  50  0   4s  6s StartYear EndYear
# 0       9800       58.60   29  13  7  626   6      1928    1948
# 1       1287       91.76    4   7  1  141  23      2022    2023
# 2       2667       55.68    5   4  2  186   5      2015    2016
# 3       1707       54.48    7  11  1  246  11      1963    1970
# 4        416       56.00   10   5  2  104   1      1930    1954

# %%
df['6s']=df['6s'].str.split(pat='+').str[0]

# %%
df.head()
# Out:
#              Player  Matches  Inns  NotOuts  Runs HighestScore    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996          334  99.94
# 1    HC Brook (ENG)       12    20        1  1181          186  62.15
# 2    AC Voges (AUS)       20    31        7  1485          269  61.87
# 3   RG Pollock (SA)       23    41        4  2256          274  60.97
# 4   GA Headley (WI)       22    40        4  2190          270  60.83
#
#   BallsFaced  StrikeRate  100  50  0   4s  6s StartYear EndYear
# 0       9800       58.60   29  13  7  626   6      1928    1948
# 1       1287       91.76    4   7  1  141  23      2022    2023
# 2       2667       55.68    5   4  2  186   5      2015    2016
# 3       1707       54.48    7  11  1  246  11      1963    1970
# 4        416       56.00   10   5  2  104   1      1930    1954

# %%
df.dtypes
# Out:
# Player           object
# Matches           int64
# Inns              int64
# NotOuts           int64
# Runs              int64
# HighestScore     object
# Avg             float64
# BallsFaced       object
# StrikeRate      float64
# 100               int64
# 50                int64
# 0                 int64
# 4s               object
# 6s               object
# StartYear        object
# EndYear          object
# dtype: object

# %%
df['HighestScore']=df['HighestScore'].astype('int')

# %%
df['BallsFaced']=df['BallsFaced'].astype('int')

# %%
df['BallsFaced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 60     8662
# 61    15525
# 62     3118
# 63     3217
# 64     2110
# Name: BallsFaced, Length: 62, dtype: int64

# %%
df.dtypes
# Out:
# Player           object
# Matches           int64
# Inns              int64
# NotOuts           int64
# Runs              int64
# HighestScore      int64
# Avg             float64
# BallsFaced        int64
# StrikeRate      float64
# 100               int64
# 50                int64
# 0                 int64
# 4s               object
# 6s               object
# StartYear        object
# EndYear          object
# dtype: object

# %%
df=df.astype({'StartYear':'int','EndYear':'int','4s':'int','6s':'int'})

# %%
df.dtypes
# Out:
# Player           object
# Matches           int64
# Inns              int64
# NotOuts           int64
# Runs              int64
# HighestScore      int64
# Avg             float64
# BallsFaced        int64
# StrikeRate      float64
# 100               int64
# 50                int64
# 0                 int64
# 4s                int64
# 6s                int64
# StartYear         int64
# EndYear           int64
# dtype: object

# %%
df.isnull().any()
# Out:
# Player          False
# Matches         False
# Inns            False
# NotOuts         False
# Runs            False
# HighestScore    False
# Avg             False
# BallsFaced      False
# StrikeRate      False
# 100             False
# 50              False
# 0               False
# 4s              False
# 6s              False
# StartYear       False
# EndYear         False
# dtype: bool

# %%
pd.set_option('display.max_rows',None)

# %%
df.head()
# Out:
#              Player  Matches  Inns  NotOuts  Runs  HighestScore    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996           334  99.94
# 1    HC Brook (ENG)       12    20        1  1181           186  62.15
# 2    AC Voges (AUS)       20    31        7  1485           269  61.87
# 3   RG Pollock (SA)       23    41        4  2256           274  60.97
# 4   GA Headley (WI)       22    40        4  2190           270  60.83
#
#    BallsFaced  StrikeRate  100  50  0   4s  6s  StartYear  EndYear
# 0        9800       58.60   29  13  7  626   6       1928     1948
# 1        1287       91.76    4   7  1  141  23       2022     2023
# 2        2667       55.68    5   4  2  186   5       2015     2016
# 3        1707       54.48    7  11  1  246  11       1963     1970
# 4         416       56.00   10   5  2  104   1       1930     1954

# %%
df.drop(50,axis=0)
# Out:
#                       Player  Matches  Inns  NotOuts   Runs  HighestScore  \
# 0           DG Bradman (AUS)       52    80       10   6996           334
# 1             HC Brook (ENG)       12    20        1   1181           186
# 2             AC Voges (AUS)       20    31        7   1485           269
# 3            RG Pollock (SA)       23    41        4   2256           274
# 4            GA Headley (WI)       22    40        4   2190           270
# 5          H Sutcliffe (ENG)       54    84        9   4555           194
# 6            E Paynter (ENG)       20    31        5   1540           243
# 7        KF Barrington (ENG)       82   131       15   6806           256
# 8             ED Weekes (WI)       48    81        5   4455           207
# 9           WR Hammond (ENG)       85   140       16   7249           336
# 10            GS Sobers (WI)       93   160       21   8032           365
# 12        KC Sangakkara (SL)      134   233       17  12400           319
# ...

# %%
# career length
df["CareerLength"]=df['EndYear']-df['StartYear']

# %%
df
# Out:
#                       Player  Matches  Inns  NotOuts   Runs  HighestScore  \
# 0           DG Bradman (AUS)       52    80       10   6996           334
# 1             HC Brook (ENG)       12    20        1   1181           186
# 2             AC Voges (AUS)       20    31        7   1485           269
# 3            RG Pollock (SA)       23    41        4   2256           274
# 4            GA Headley (WI)       22    40        4   2190           270
# 5          H Sutcliffe (ENG)       54    84        9   4555           194
# 6            E Paynter (ENG)       20    31        5   1540           243
# 7        KF Barrington (ENG)       82   131       15   6806           256
# 8             ED Weekes (WI)       48    81        5   4455           207
# 9           WR Hammond (ENG)       85   140       16   7249           336
# 10            GS Sobers (WI)       93   160       21   8032           365
# 12        KC Sangakkara (SL)      134   233       17  12400           319
# ...

# %%
df['CareerLength'].mean()
# Out:
# np.float64(13.193548387096774)

# %%
#avg StrikeRate for cricketers who played over 10 years
df[df['CareerLength']>10]['StrikeRate'].mean()
# Out:
# np.float64(47.94681818181819)

# %%
df[df['StartYear']<1960]['Player'].count()
# Out:
# np.int64(23)

# %%
df['Country'] = df['Player'].str.split(pat='(').str[1]

# %%
df['Country']
# Out:
# 0         AUS)
# 1         ENG)
# 2         AUS)
# 3          SA)
# 4          WI)
# 5         ENG)
# 6         ENG)
# 7         ENG)
# 8          WI)
# 9         ENG)
# 10         WI)
# 12         SL)
# 13        AUS)
# 14        ENG)
# 15         WI)
# 16        ENG)
# 17     ICC/SA)
# 18        ENG)
# 19         NZ)
# 20         WI)
# 21     ICC/WI)
# 22        IND)
# 23        AUS)
# 24         SA)
# 25        IND)
# 27        PAK)
# 28    ICC/IND)
# 29        PAK)
# 30        PAK)
# 31        AUS)
# 32        AUS)
# 33        ZIM)
# 34        AUS)
# 35         WI)
# 36        IND)
# 37        AUS)
# 38        AUS)
# 39         SA)
# 40        AUS)
# 41         NZ)
# 42         WI)
# 43        ENG)
# 44         SL)
# 45        ENG)
# 46    ICC/PAK)
# 47        AUS)
# 48         WI)
# 49        ENG)
# 50    ICC/IND)
# 51        PAK)
# 52        IND)
# 53        AUS)
# 54         SA)
# 55         SA)
# 56        ENG)
# 57         SL)
# 59        AUS)
# 60        AUS)
# ...

# %%
df['Country'] = df['Country'].str.split(pat='(').str[1]

# %%
df['Country']
# Out:
# 0         AUS
# 1         ENG
# 2         AUS
# 3          SA
# 4          WI
# 5         ENG
# 6         ENG
# 7         ENG
# 8          WI
# 9         ENG
# 10         WI
# 12         SL
# 13        AUS
# 14        ENG
# 15         WI
# 16        ENG
# 17     ICC/SA
# 18        ENG
# 19         NZ
# 20         WI
# 21     ICC/WI
# 22        IND
# 23        AUS
# 24         SA
# 25        IND
# 27        PAK
# 28    ICC/IND
# 29        PAK
# 30        PAK
# 31        AUS
# 32        AUS
# 33        ZIM
# 34        AUS
# 35         WI
# 36        IND
# 37        AUS
# 38        AUS
# 39         SA
# 40        AUS
# 41         NZ
# 42         WI
# 43        ENG
# 44         SL
# 45        ENG
# 46    ICC/PAK
# 47        AUS
# 48         WI
# 49        ENG
# 50    ICC/IND
# 51        PAK
# 52        IND
# 53        AUS
# 54         SA
# 55         SA
# 56        ENG
# 57         SL
# 59        AUS
# 60        AUS
# 61     ICC/SA
# 62        AUS
# 63        AUS
# 64        ENG
# ...

# %%
# Out:
#                       Player  Matches  Inns  NotOuts   Runs  HighestScore  \
# 0           DG Bradman (AUS)       52    80       10   6996           334
# 1             HC Brook (ENG)       12    20        1   1181           186
# 2             AC Voges (AUS)       20    31        7   1485           269
# 3            RG Pollock (SA)       23    41        4   2256           274
# 4            GA Headley (WI)       22    40        4   2190           270
# 5          H Sutcliffe (ENG)       54    84        9   4555           194
# 6            E Paynter (ENG)       20    31        5   1540           243
# 7        KF Barrington (ENG)       82   131       15   6806           256
# 8             ED Weekes (WI)       48    81        5   4455           207
# 9           WR Hammond (ENG)       85   140       16   7249           336
# 10            GS Sobers (WI)       93   160       21   8032           365
# 12        KC Sangakkara (SL)      134   233       17  12400           319
# ...

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]

# %%
df.head()
# Out:
#         Player  Matches  Inns  NotOuts  Runs  HighestScore    Avg  BallsFaced  \
# 0  DG Bradman        52    80       10  6996           334  99.94        9800
# 1    HC Brook        12    20        1  1181           186  62.15        1287
# 2    AC Voges        20    31        7  1485           269  61.87        2667
# 3  RG Pollock        23    41        4  2256           274  60.97        1707
# 4  GA Headley        22    40        4  2190           270  60.83         416
#
#    StrikeRate  100  50  0   4s  6s  StartYear  EndYear  CareerLength Country
# 0       58.60   29  13  7  626   6       1928     1948            20     AUS
# 1       91.76    4   7  1  141  23       2022     2023             1     ENG
# 2       55.68    5   4  2  186   5       2015     2016             1     AUS
# 3       54.48    7  11  1  246  11       1963     1970             7      SA
# 4       56.00   10   5  2  104   1       1930     1954            24      WI

# %%
df.groupby('Country')['HighestScore'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: HighestScore, dtype: int64

# %%
df.groupby('Country')['HighestScore'].max().to_frame('HighestInCountry').reset_index().sort_values('HighestInCountry',ascending = False)
# Out:
#     Country  HighestInCountry
# 5    ICC/WI               400
# 0       AUS               380
# 10       SL               374
# 11       WI               365
# 1       ENG               364
# 3   ICC/PAK               329
# 2   ICC/IND               319
# 8       PAK               313
# 9        SA               278
# 4    ICC/SA               277
# 6       IND               254
# 7        NZ               251
# 12      ZIM               232

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.384615  20.846154   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000

# %%
df
# Out:
#                Player  Matches  Inns  NotOuts   Runs  HighestScore    Avg  \
# 0         DG Bradman        52    80       10   6996           334  99.94
# 1           HC Brook        12    20        1   1181           186  62.15
# 2           AC Voges        20    31        7   1485           269  61.87
# 3         RG Pollock        23    41        4   2256           274  60.97
# 4         GA Headley        22    40        4   2190           270  60.83
# 5        H Sutcliffe        54    84        9   4555           194  60.73
# 6          E Paynter        20    31        5   1540           243  59.23
# 7      KF Barrington        82   131       15   6806           256  58.67
# 8          ED Weekes        48    81        5   4455           207  58.61
# 9         WR Hammond        85   140       16   7249           336  58.45
# 10         GS Sobers        93   160       21   8032           365  57.78
# 12     KC Sangakkara       134   233       17  12400           319  57.40
# ...

# %%
df.to_csv('New_Cricket_Stats.csv')
